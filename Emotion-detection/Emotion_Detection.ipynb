# %%
# !which python
# Out:
# /Users/rguarise/Documents/Personal/PFE/Emotion-detection/.venv/bin/python

# %%
# %% capture
# !unzip data/dataset.zip
# Out:
# UsageError: Cell magic `%%` not found.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.layers import Flatten, Dense
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator , img_to_array, load_img
from keras.applications.mobilenet import MobileNet, preprocess_input 
from keras.losses import categorical_crossentropy
# Out:
# 2023-08-10 22:23:10.576745: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# #  Building our Model To train the data

# %%
# Working with pre trained model 

base_model = MobileNet( input_shape=(224,224,3), include_top= False )

for layer in base_model.layers:
  layer.trainable = False


x = Flatten()(base_model.output)
x = Dense(units=7 , activation='softmax' )(x)

# creating our model.
model = Model(base_model.input, x)

# %%
model.compile(optimizer='adam', loss= categorical_crossentropy , metrics=['accuracy']  )

# %% [markdown]
# # Preparing our data using data generator

# %%
train_datagen = ImageDataGenerator(
     zoom_range = 0.2, 
     shear_range = 0.2, 
     horizontal_flip=True, 
     rescale = 1./255
)

train_data = train_datagen.flow_from_directory(directory= "./data/train", 
                                               target_size=(224,224), 
                                               batch_size=32,
                                  )


train_data.class_indices
# Out:
# Found 28709 images belonging to 7 classes.
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
val_datagen = ImageDataGenerator(rescale = 1./255 )

val_data = val_datagen.flow_from_directory(directory= "./data/test", 
                                           target_size=(224,224), 
                                           batch_size=32,
                                  )
# Out:
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # visualizaing the data that is fed to train data gen

# %%
# to visualize the images in the traing data denerator 

t_img , label = train_data.next()

#-----------------------------------------------------------------------------
# function when called will prot the images 
def plotImages(img_arr, label):
  """
  input  :- images array 
  output :- plots the images 
  """
  count = 0
  for im, l in zip(img_arr,label) :
    plt.imshow(im)
    plt.title(im.shape)
    plt.axis = False
    plt.show()
    
    count += 1
    if count == 10:
      break

#-----------------------------------------------------------------------------
# function call to plot the images 
plotImages(t_img, label)

# %% [markdown]
# # having early stopping and model check point

# %%
## having early stopping and model check point 

from keras.callbacks import ModelCheckpoint, EarlyStopping

# early stopping
es = EarlyStopping(monitor='val_accuracy', min_delta= 0.01 , patience= 5, verbose= 1, mode='auto')

# model check point
mc = ModelCheckpoint(filepath="best_model.h5", monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode = 'auto')

# puting call back in a list 
call_back = [es, mc]

# %%
hist = model.fit_generator(train_data, 
                           steps_per_epoch= 10, 
                           epochs= 30, 
                           validation_data= val_data, 
                           validation_steps= 8, 
                           callbacks=[es,mc])
# Out:
# /var/folders/4w/jy_v2z310w37cq_28b_31fg0lk7sbc/T/ipykernel_11263/564963302.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(train_data,
# Epoch 1/30
# 10/10 [==============================] - ETA: 0s - loss: 23.1949 - accuracy: 0.2313
# Epoch 1: val_accuracy improved from -inf to 0.30078, saving model to best_model.h5
# 10/10 [==============================] - 11s 989ms/step - loss: 23.1949 - accuracy: 0.2313 - val_loss: 14.0601 - val_accuracy: 0.3008
# Epoch 2/30
# /Users/rguarise/Documents/Personal/PFE/Emotion-detection/.venv/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 10/10 [==============================] - ETA: 0s - loss: 14.2096 - accuracy: 0.2594
# Epoch 2: val_accuracy improved from 0.30078 to 0.41406, saving model to best_model.h5
# 10/10 [==============================] - 9s 936ms/step - loss: 14.2096 - accuracy: 0.2594 - val_loss: 6.5171 - val_accuracy: 0.4141
# Epoch 3/30
# 10/10 [==============================] - ETA: 0s - loss: 6.9992 - accuracy: 0.3875
# Epoch 3: val_accuracy did not improve from 0.41406
# 10/10 [==============================] - 9s 921ms/step - loss: 6.9992 - accuracy: 0.3875 - val_loss: 5.9591 - val_accuracy: 0.3945
# Epoch 4/30
# 10/10 [==============================] - ETA: 0s - loss: 7.9839 - accuracy: 0.3187
# Epoch 4: val_accuracy did not improve from 0.41406
# 10/10 [==============================] - 9s 940ms/step - loss: 7.9839 - accuracy: 0.3187 - val_loss: 7.7335 - val_accuracy: 0.4023
# Epoch 5/30
# 10/10 [==============================] - ETA: 0s - loss: 7.3326 - accuracy: 0.3594
# Epoch 5: val_accuracy did not improve from 0.41406
# 10/10 [==============================] - 9s 945ms/step - loss: 7.3326 - accuracy: 0.3594 - val_loss: 5.1143 - val_accuracy: 0.3789
# Epoch 6/30
# 10/10 [==============================] - ETA: 0s - loss: 5.6447 - accuracy: 0.4156
# Epoch 6: val_accuracy improved from 0.41406 to 0.53516, saving model to best_model.h5
# 10/10 [==============================] - 9s 970ms/step - loss: 5.6447 - accuracy: 0.4156 - val_loss: 3.5461 - val_accuracy: 0.5352
# Epoch 7/30
# 10/10 [==============================] - ETA: 0s - loss: 6.5227 - accuracy: 0.3844
# Epoch 7: val_accuracy did not improve from 0.53516
# 10/10 [==============================] - 9s 952ms/step - loss: 6.5227 - accuracy: 0.3844 - val_loss: 5.4986 - val_accuracy: 0.4062
# Epoch 8/30
# 10/10 [==============================] - ETA: 0s - loss: 6.1774 - accuracy: 0.3750
# Epoch 8: val_accuracy did not improve from 0.53516
# 10/10 [==============================] - 9s 952ms/step - loss: 6.1774 - accuracy: 0.3750 - val_loss: 4.6565 - val_accuracy: 0.4727
# Epoch 9/30
# 10/10 [==============================] - ETA: 0s - loss: 5.7032 - accuracy: 0.4094
# Epoch 9: val_accuracy did not improve from 0.53516
# 10/10 [==============================] - 9s 928ms/step - loss: 5.7032 - accuracy: 0.4094 - val_loss: 5.1059 - val_accuracy: 0.4648
# Epoch 10/30
# 10/10 [==============================] - ETA: 0s - loss: 4.9342 - accuracy: 0.4531
# Epoch 10: val_accuracy did not improve from 0.53516
# 10/10 [==============================] - 9s 949ms/step - loss: 4.9342 - accuracy: 0.4531 - val_loss: 5.1729 - val_accuracy: 0.4062
# Epoch 11/30
# 10/10 [==============================] - ETA: 0s - loss: 6.3259 - accuracy: 0.3562
# Epoch 11: val_accuracy did not improve from 0.53516
# 10/10 [==============================] - 9s 919ms/step - loss: 6.3259 - accuracy: 0.3562 - val_loss: 4.8147 - val_accuracy: 0.4375
# Epoch 11: early stopping

# %%
# Loading the best fit model 
from keras.models import load_model
model = load_model("./best_model.h5")

# %%
h =  hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
# just to map o/p values 
op = dict(zip( train_data.class_indices.values(), train_data.class_indices.keys()))

# %%
# path for the image to see if it predics correct class

path = "./data/test/angry/PrivateTest_1054527.jpg"
img = load_img(path, target_size=(224,224) )

i = img_to_array(img)/255
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))

print(f" the image is of {op[pred]}")

# to display the image  
plt.imshow(input_arr[0])
plt.title("input image")
plt.show()
# Out:
# 1/1 [==============================] - 0s 488ms/step
#  the image is of sad
